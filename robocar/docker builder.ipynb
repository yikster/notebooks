# %%
# !ls *.sh
# Out:
# build_and_push.sh

# %%
# !cat build_and_push.sh
# Out:
# %%sh
#
# # Update the image variable with your Robocar name (must use all lowercase)
# image=robocar-yikster
# cd /home/ec2-user/SageMaker/donkey/sagetrain/container
#
# #!/usr/bin/env bash
#
# # This script shows how to build the Docker image and push it to ECR to be ready for use
# # by SageMaker.
#
# # The argument to this script is the image name. This will be used as the image on the local
# # machine and combined with the account and region to form the repository name for ECR.
#
# # if [ "$image" == "" ]
# #then
# #    echo "Usage: $0 <image-name>"
# #    exit 1
# #fi
#
# chmod +x customkeras/train
#
# # Get the account number associated with the current IAM credentials
# account=$(aws sts get-caller-identity --query Account --output text)
#
# if [ $? -ne 0 ]
# then
#     exit 255
# fi
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-ap-northeast-1}
#
# ...

# %%
# !./build_and_push.sh
# Out:
# ./build_and_push.sh: line 1: fg: no job control
# ./build_and_push.sh: line 5: cd: /home/ec2-user/SageMaker/donkey/sagetrain/container: No such file or directory
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# Login Succeeded
# Stopping docker: [  OK  ]
# Starting docker:	.[  OK  ]
# Sending build context to Docker daemon  15.54MB
# Step 1/40 : FROM nvidia/cuda:9.0-base-ubuntu16.04
# 9.0-base-ubuntu16.04: Pulling from nvidia/cuda
#
# 166ec614: Pulling fs layer
# acff238f: Pulling fs layer
# acd28e10: Pulling fs layer
# 3351ecad: Pulling fs layer
# ebadcbf7: Pulling fs layer
# e415719f: Pulling fs layer
# a756cd3a: Pulling fs layer
# Digest: sha256:18f5228f88f18055aed81897bb1f41edd5f3ef12de2c2e87a5fccec0a1c073e8
# Status: Downloaded newer image for nvidia/cuda:9.0-base-ubuntu16.04
#  ---> 34d9d9eeafd5
# Step 2/40 : MAINTAINER Amazon AI
#  ---> Running in a6070caba07e
# Removing intermediate container a6070caba07e
#  ---> 6f4504754344
# ...
